# %% [markdown]
# # DSX ML Lab Installation Steps (Decison Tree)

# %% [markdown]
# ## Installing Brunel

# %%
try(system("pip install brunel --upgrade --user", intern = TRUE, ignore.stderr = TRUE))
# Out:
#  [1] "Collecting brunel"
#  [2] "  Downloading brunel-2.3.tar.gz (2.1MB)"
#  [3] "Collecting pandas (from brunel)"
#  [4] "  Downloading pandas-0.20.1-cp27-cp27m-manylinux1_x86_64.whl (22.3MB)"
#  [5] "Collecting jinja2 (from brunel)"
#  [6] "  Downloading Jinja2-2.9.6-py2.py3-none-any.whl (340kB)"
#  [7] "Collecting ipython (from brunel)"
#  [8] "  Downloading ipython-5.3.0-py2-none-any.whl (750kB)"
#  [9] "Requirement already up-to-date: jupyter-pip in /usr/local/src/bluemix_jupyter_bundle.v44/notebook/lib/python2.7/site-packages (from brunel)"
# [10] "Collecting JPype1 (from brunel)"
# [11] "  Downloading JPype1-0.6.2.tar.gz (147kB)"
# [12] "Collecting pytz>=2011k (from pandas->brunel)"
# [13] "  Downloading pytz-2017.2-py2.py3-none-any.whl (484kB)"
# [14] "Collecting numpy>=1.7.0 (from pandas->brunel)"
# [15] "  Downloading numpy-1.12.1-cp27-cp27m-manylinux1_x86_64.whl (16.5MB)"
# [16] "Requirement already up-to-date: python-dateutil in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s622-2115255598c3b5-f830564e03b3/.local/lib/python2.7/site-packages (from pandas->brunel)"
# [17] "Collecting MarkupSafe>=0.23 (from jinja2->brunel)"
# [18] "  Downloading MarkupSafe-1.0.tar.gz"
# [19] "Collecting pygments (from ipython->brunel)"
# [20] "  Downloading Pygments-2.2.0-py2.py3-none-any.whl (841kB)"
# [21] "Collecting setuptools>=18.5 (from ipython->brunel)"
# [22] "  Downloading setuptools-35.0.2-py2.py3-none-any.whl (390kB)"
# [23] "Collecting prompt-toolkit<2.0.0,>=1.0.4 (from ipython->brunel)"
# [24] "  Downloading prompt_toolkit-1.0.14-py2-none-any.whl (248kB)"
# [25] "Requirement already up-to-date: backports.shutil-get-terminal-size; python_version == \"2.7\" in /usr/local/src/bluemix_jupyter_bundle.v44/notebook/lib/python2.7/site-packages (from ipython->brunel)"
# [26] "Requirement already up-to-date: pickleshare in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s622-2115255598c3b5-f830564e03b3/.local/lib/python2.7/site-packages (from ipython->brunel)"
# [27] "Collecting traitlets>=4.2 (from ipython->brunel)"
# [28] "  Downloading traitlets-4.3.2-py2.py3-none-any.whl (74kB)"
# [29] "Requirement already up-to-date: pexpect; sys_platform != \"win32\" in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s622-2115255598c3b5-f830564e03b3/.local/lib/python2.7/site-packages (from ipython->brunel)"
# [30] "Collecting pathlib2; python_version == \"2.7\" or python_version == \"3.3\" (from ipython->brunel)"
# [31] "  Downloading pathlib2-2.2.1-py2.py3-none-any.whl"
# [32] "Requirement already up-to-date: simplegeneric>0.8 in /usr/local/src/bluemix_jupyter_bundle.v44/notebook/lib/python2.7/site-packages (from ipython->brunel)"
# [33] "Collecting decorator (from ipython->brunel)"
# [34] "  Downloading decorator-4.0.11-py2.py3-none-any.whl"
# [35] "Requirement already up-to-date: six>=1.5 in /usr/local/src/bluemix_jupyter_bundle.v44/notebook/lib/python2.7/site-packages (from python-dateutil->pandas->brunel)"
# [36] "Collecting appdirs>=1.4.0 (from setuptools>=18.5->ipython->brunel)"
# [37] "  Downloading appdirs-1.4.3-py2.py3-none-any.whl"
# [38] "Requirement already up-to-date: packaging>=16.8 in /usr/local/src/bluemix_jupyter_bundle.v44/notebook/lib/python2.7/site-packages (from setuptools>=18.5->ipython->brunel)"
# [39] "Requirement already up-to-date: wcwidth in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s622-2115255598c3b5-f830564e03b3/.local/lib/python2.7/site-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->brunel)"
# [40] "Requirement already up-to-date: enum34; python_version == \"2.7\" in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s622-2115255598c3b5-f830564e03b3/.local/lib/python2.7/site-packages (from traitlets>=4.2->ipython->brunel)"
# [41] "Collecting ipython-genutils (from traitlets>=4.2->ipython->brunel)"
# [42] "  Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl"
# [43] "Requirement already up-to-date: ptyprocess>=0.5 in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s622-2115255598c3b5-f830564e03b3/.local/lib/python2.7/site-packages (from pexpect; sys_platform != \"win32\"->ipython->brunel)"
# [44] "Collecting scandir; python_version < \"3.5\" (from pathlib2; python_version == \"2.7\" or python_version == \"3.3\"->ipython->brunel)"
# [45] "  Downloading scandir-1.5.tar.gz"
# [46] "Collecting pyparsing (from packaging>=16.8->setuptools>=18.5->ipython->brunel)"
# [47] "  Downloading pyparsing-2.2.0-py2.py3-none-any.whl (56kB)"
# [48] "Building wheels for collected packages: brunel, JPype1, MarkupSafe, scandir"
# [49] "  Running setup.py bdist_wheel for brunel: started"
# [50] "  Running setup.py bdist_wheel for brunel: finished with status 'done'"
# [51] "  Stored in directory: /gpfs/fs01/user/s622-2115255598c3b5-f830564e03b3/.cache/pip/wheels/c6/94/ba/4b6c57d645b15e965f913b5ef669e1e6e412e87b2445593e6b"
# [52] "  Running setup.py bdist_wheel for JPype1: started"
# [53] "  Running setup.py bdist_wheel for JPype1: finished with status 'done'"
# [54] "  Stored in directory: /gpfs/fs01/user/s622-2115255598c3b5-f830564e03b3/.cache/pip/wheels/8e/f3/e6/a1250b8e8d2bd105f4dd21b1dc801dbcf5d815592443bfe741"
# [55] "  Running setup.py bdist_wheel for MarkupSafe: started"
# [56] "  Running setup.py bdist_wheel for MarkupSafe: finished with status 'done'"
# [57] "  Stored in directory: /gpfs/fs01/user/s622-2115255598c3b5-f830564e03b3/.cache/pip/wheels/88/a7/30/e39a54a87bcbe25308fa3ca64e8ddc75d9b3e5afa21ee32d57"
# [58] "  Running setup.py bdist_wheel for scandir: started"
# [59] "  Running setup.py bdist_wheel for scandir: finished with status 'done'"
# [60] "  Stored in directory: /gpfs/fs01/user/s622-2115255598c3b5-f830564e03b3/.cache/pip/wheels/47/af/a2/eb591a17e9709a17d8b53696f6ad89914a05eaf9c091f36e18"
# [61] "Successfully built brunel JPype1 MarkupSafe scandir"
# [62] "Installing collected packages: pytz, numpy, pandas, MarkupSafe, jinja2, pygments, appdirs, setuptools, prompt-toolkit, ipython-genutils, decorator, traitlets, scandir, pathlib2, ipython, JPype1, brunel, pyparsing"
# [63] "  Found existing installation: pytz 2016.7"
# [64] "    Uninstalling pytz-2016.7:"
# [65] "      Successfully uninstalled pytz-2016.7"
# [66] "  Found existing installation: numpy 1.11.2"
# [67] "    Uninstalling numpy-1.11.2:"
# [68] "      Successfully uninstalled numpy-1.11.2"
# [69] "  Found existing installation: pandas 0.19.1"
# [70] "    Uninstalling pandas-0.19.1:"
# [71] "      Successfully uninstalled pandas-0.19.1"
# [72] "  Found existing installation: Pygments 2.1.3"
# [73] "    Uninstalling Pygments-2.1.3:"
# [74] "      Successfully uninstalled Pygments-2.1.3"
# [75] "  Found existing installation: setuptools 29.0.1"
# [76] "    Uninstalling setuptools-29.0.1:"
# [77] "      Successfully uninstalled setuptools-29.0.1"
# [78] "  Found existing installation: prompt-toolkit 1.0.9"
# [79] "    Uninstalling prompt-toolkit-1.0.9:"
# [80] "      Successfully uninstalled prompt-toolkit-1.0.9"
# [81] "  Found existing installation: decorator 4.0.10"
# [82] "    Uninstalling decorator-4.0.10:"
# [83] "      Successfully uninstalled decorator-4.0.10"
# [84] "  Found existing installation: traitlets 4.3.1"
# [85] "    Uninstalling traitlets-4.3.1:"
# [86] "      Successfully uninstalled traitlets-4.3.1"
# [87] "  Found existing installation: pathlib2 2.1.0"
# [88] "    Uninstalling pathlib2-2.1.0:"
# [89] "      Successfully uninstalled pathlib2-2.1.0"
# [90] "  Found existing installation: ipython 5.1.0"
# [91] "    Uninstalling ipython-5.1.0:"
# [92] "      Successfully uninstalled ipython-5.1.0"
# [93] "  Found existing installation: brunel 2.0"
# [94] "    Uninstalling brunel-2.0:"
# [95] "      Successfully uninstalled brunel-2.0"
# [96] "Successfully installed JPype1-0.6.2 MarkupSafe-1.0 appdirs-1.4.3 brunel-2.3 decorator-4.0.11 ipython-5.3.0 ipython-genutils-0.2.0 jinja2-2.9.6 numpy-1.12.1 pandas-0.20.1 pathlib2-2.2.1 prompt-toolkit-1.0.14 pygments-2.2.0 pyparsing-2.2.0 pytz-2017.2 scandir-1.5 setuptools-35.0.2 traitlets-4.3.2"

# %% [markdown]
# ## Installing supporting R packages

# %% [markdown]
# ### Installing R packages for Brunel

# %%
install.packages("devtools")
# Out:
# Installing package into ‘/gpfs/global_fs01/sym_shared/YPProdSpark/user/s622-2115255598c3b5-f830564e03b3/R/libs’
# (as ‘lib’ is unspecified)

# %%
devtools::install_github("Brunel-Visualization/Brunel", subdir="R", ref="master2.1", force=TRUE)
# Out:
# Downloading GitHub repo Brunel-Visualization/Brunel@master2.1
# from URL https://api.github.com/repos/Brunel-Visualization/Brunel/zipball/master2.1
# Installing brunel
# '/usr/local/src/bluemix_jupyter_bundle/R/lib64/R/bin/R' --no-site-file  \
#   --no-environ --no-save --no-restore --quiet CMD INSTALL  \
#   '/gpfs/global_fs01/sym_shared/YPProdSpark/user/s622-2115255598c3b5-f830564e03b3/notebook/tmp/Rtmpggsylf/devtools9eb42a77786/Brunel-Visualization-Brunel-e22ad23/R'  \
#   --library='/gpfs/global_fs01/sym_shared/YPProdSpark/user/s622-2115255598c3b5-f830564e03b3/R/libs'  \
#   --install-tests

# %% [markdown]
# ### Installing R packages for machine learning

# %%
install.packages("arules")

# %%
install.packages("C50")
# Out:
# Installing package into '/gpfs/global_fs01/sym_shared/YPProdSpark/user/s622-2115255598c3b5-f830564e03b3/R/libs'
# (as 'lib' is unspecified)
# also installing the dependencies 'Formula', 'partykit'

# %%
# a package supporting model transformations for visualization
devtools::install_github("ibmdataworks/datafirst", subdir="datascientist/machinelearning/sigmoml", force=TRUE)
# Out:
# Downloading GitHub repo ibmdataworks/datafirst@master
# from URL https://api.github.com/repos/ibmdataworks/datafirst/zipball/master
# Installing sigmoml
# Installing plyr
# Installing Rcpp
# '/usr/local/src/bluemix_jupyter_bundle/R/lib64/R/bin/R' --no-site-file  \
#   --no-environ --no-save --no-restore --quiet CMD INSTALL  \
#   '/gpfs/global_fs01/sym_shared/YPProdSpark/user/s622-2115255598c3b5-f830564e03b3/notebook/tmp/RtmpZEMB9S/devtools9409180366ff/Rcpp'  \
#   --library='/gpfs/global_fs01/sym_shared/YPProdSpark/user/s622-2115255598c3b5-f830564e03b3/R/libs'  \
#   --install-tests
#
# '/usr/local/src/bluemix_jupyter_bundle/R/lib64/R/bin/R' --no-site-file  \
#   --no-environ --no-save --no-restore --quiet CMD INSTALL  \
#   '/gpfs/global_fs01/sym_shared/YPProdSpark/user/s622-2115255598c3b5-f830564e03b3/notebook/tmp/RtmpZEMB9S/devtools94096c314d7a/plyr'  \
#   --library='/gpfs/global_fs01/sym_shared/YPProdSpark/user/s622-2115255598c3b5-f830564e03b3/R/libs'  \
#   --install-tests
#
# '/usr/local/src/bluemix_jupyter_bundle/R/lib64/R/bin/R' --no-site-file  \
#   --no-environ --no-save --no-restore --quiet CMD INSTALL  \
#   '/gpfs/global_fs01/sym_shared/YPProdSpark/user/s622-2115255598c3b5-f830564e03b3/notebook/tmp/RtmpZEMB9S/devtools940937158da2/ibmdataworks-datafirst-ac31960/datascientist/machinelearning/sigmoml'  \
#   --library='/gpfs/global_fs01/sym_shared/YPProdSpark/user/s622-2115255598c3b5-f830564e03b3/R/libs'  \
#   --install-tests
